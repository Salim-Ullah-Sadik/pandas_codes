# %%
import pandas as pd

# %%
missing_data =pd.read_csv('./Book1.csv')
missing_data
# Out:
#    Diastolic_BP  Skin_Fold  Serum
# 0     72.000000       35.0    NaN
# 1     66.000000       29.0    NaN
# 2     64.000000        NaN    NaN
# 3     66.000000       23.0   94.0
# 4     40.000000       35.0  168.0
# 5     74.000000        NaN    NaN
# 6     50.000000       32.0   88.0
# 7     35.300000        NaN    NaN
# 8    220.666667       45.0  543.0

# %%
missing_data.dropna()
# Out:
#    Diastolic_BP  Skin_Fold  Serum
# 3     66.000000       23.0   94.0
# 4     40.000000       35.0  168.0
# 6     50.000000       32.0   88.0
# 8    220.666667       45.0  543.0

# %%
missing_data
# Out:
#    Diastolic_BP  Skin_Fold  Serum
# 0     72.000000       35.0    NaN
# 1     66.000000       29.0    NaN
# 2     64.000000        NaN    NaN
# 3     66.000000       23.0   94.0
# 4     40.000000       35.0  168.0
# 5     74.000000        NaN    NaN
# 6     50.000000       32.0   88.0
# 7     35.300000        NaN    NaN
# 8    220.666667       45.0  543.0

# %%
missing_data=missing_data.dropna()

# %%
missing_data
# Out:
#    Diastolic_BP  Skin_Fold  Serum
# 3     66.000000       23.0   94.0
# 4     40.000000       35.0  168.0
# 6     50.000000       32.0   88.0
# 8    220.666667       45.0  543.0

# %%
missing_data.to_csv("cleaned_data.csv",index=False)

# %%
data=pd.read_csv('./cleaned_data.csv')
data
# Out:
#    Diastolic_BP  Skin_Fold  Serum
# 0     66.000000       23.0   94.0
# 1     40.000000       35.0  168.0
# 2     50.000000       32.0   88.0
# 3    220.666667       45.0  543.0

# %%
serial_num=pd.Series([2,4,4,6])

# %%
data["serial_num"]=serial_num

# %%
data
# Out:
#    Diastolic_BP  Skin_Fold  Serum  serial_num
# 0     66.000000       23.0   94.0           2
# 1     40.000000       35.0  168.0           4
# 2     50.000000       32.0   88.0           4
# 3    220.666667       45.0  543.0           6

# %%
data["serial_num"].fillna(4)
# Out:
# 0    2
# 1    4
# 2    4
# 3    6
# Name: serial_num, dtype: int64

# %%
data
# Out:
#    Diastolic_BP  Skin_Fold  Serum  serial_num
# 0     66.000000       23.0   94.0           2
# 1     40.000000       35.0  168.0           4
# 2     50.000000       32.0   88.0           4
# 3    220.666667       45.0  543.0           6

# %%
data["serial_num"].fillna(6,inplace=True)
data
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24316\3649454385.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["serial_num"].fillna(6,inplace=True)
#    Diastolic_BP  Skin_Fold  Serum  serial_num
# 0     66.000000       23.0   94.0           2
# 1     40.000000       35.0  168.0           4
# 2     50.000000       32.0   88.0           4
# 3    220.666667       45.0  543.0           6

# %%
kg=[20,40,60,80]
data["KG"]=kg

# %%
data
# Out:
#    Diastolic_BP  Skin_Fold  Serum  serial_num  KG
# 0     66.000000       23.0   94.0           2  20
# 1     40.000000       35.0  168.0           4  40
# 2     50.000000       32.0   88.0           4  60
# 3    220.666667       45.0  543.0           6  80

# %%
data["Fees"]=data["KG"]*data["serial_num"]

# %%
data
# Out:
#    Diastolic_BP  Skin_Fold  Serum  serial_num  KG  Fees
# 0     66.000000       23.0   94.0           2  20    40
# 1     40.000000       35.0  168.0           4  40   160
# 2     50.000000       32.0   88.0           4  60   240
# 3    220.666667       45.0  543.0           6  80   480

# %%
data["Constant"]=4
data
# Out:
#    Diastolic_BP  Skin_Fold  Serum  serial_num  KG  Fees  Constant
# 0     66.000000       23.0   94.0           2  20    40         4
# 1     40.000000       35.0  168.0           4  40   160         4
# 2     50.000000       32.0   88.0           4  60   240         4
# 3    220.666667       45.0  543.0           6  80   480         4

# %%
data["Patient_Ok"]=True
data
# Out:
#    Diastolic_BP  Skin_Fold  Serum  serial_num  KG  Fees  Constant  Patient_Ok
# 0     66.000000       23.0   94.0           2  20    40         4        True
# 1     40.000000       35.0  168.0           4  40   160         4        True
# 2     50.000000       32.0   88.0           4  60   240         4        True
# 3    220.666667       45.0  543.0           6  80   480         4        True

# %%
data.drop("Patient_Ok",axis=1)
# Out:
#    Diastolic_BP  Skin_Fold  Serum  serial_num  KG  Fees  Constant
# 0     66.000000       23.0   94.0           2  20    40         4
# 1     40.000000       35.0  168.0           4  40   160         4
# 2     50.000000       32.0   88.0           4  60   240         4
# 3    220.666667       45.0  543.0           6  80   480         4

# %%
data.drop("KG",axis=1)
# Out:
#    Diastolic_BP  Skin_Fold  Serum  serial_num  Fees  Constant  Patient_Ok
# 0     66.000000       23.0   94.0           2    40         4        True
# 1     40.000000       35.0  168.0           4   160         4        True
# 2     50.000000       32.0   88.0           4   240         4        True
# 3    220.666667       45.0  543.0           6   480         4        True

# %%
data=data.drop("Fees",axis=1)

# %%
data
# Out:
#    Diastolic_BP  Skin_Fold  Serum  serial_num  Constant  Patient_Ok
# 0     66.000000       23.0   94.0           2         4        True
# 1     40.000000       35.0  168.0           4         4        True
# 2     50.000000       32.0   88.0           4         4        True
# 3    220.666667       45.0  543.0           6         4        True

# %%
data_1=data.sample(frac=0.5)

# %%
data_1
# Out:
#    Diastolic_BP  Skin_Fold  Serum  serial_num  Constant  Patient_Ok
# 2     50.000000       32.0   88.0           4         4        True
# 3    220.666667       45.0  543.0           6         4        True

# %%
data["serial_num"]=data["serial_num"].apply(lambda x:x*10)

# %%
data
# Out:
#    Diastolic_BP  Skin_Fold  Serum  serial_num  Constant  Patient_Ok
# 0     66.000000       23.0   94.0          20         4        True
# 1     40.000000       35.0  168.0          40         4        True
# 2     50.000000       32.0   88.0          40         4        True
# 3    220.666667       45.0  543.0          60         4        True
